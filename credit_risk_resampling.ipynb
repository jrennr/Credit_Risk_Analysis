# %%
import warnings
warnings.filterwarnings('ignore')

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jrgar\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     dask-2022.2.1              |     pyhd3eb1b0_0           5 KB
#     dask-core-2022.2.1         |     pyhd3eb1b0_0         747 KB
#     distributed-2022.2.1       |     pyhd3eb1b0_0         659 KB
#     ------------------------------------------------------------
#                                            Total:         1.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   anaconda-client    pkgs/main/win-64::anaconda-client-1.12.0-py39haa95532_0 None
#   arrow              pkgs/main/win-64::arrow-1.2.3-py39haa95532_1 None
#   astroid            pkgs/main/win-64::astroid-2.14.2-py39haa95532_0 None
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0 None
#   attrs              pkgs/main/win-64::attrs-22.1.0-py39haa95532_0 None
#   babel              pkgs/main/win-64::babel-2.11.0-py39haa95532_0 None
#   beautifulsoup4     pkgs/main/win-64::beautifulsoup4-4.12.2-py39haa95532_0 None
#   black              pkgs/main/win-64::black-23.3.0-py39haa95532_0 None
#   blosc              pkgs/main/win-64::blosc-1.21.3-h6c2663c_0 None
#   bokeh              pkgs/main/win-64::bokeh-3.1.1-py39h9909e9c_0 None
#   botocore           pkgs/main/win-64::botocore-1.27.59-py39haa95532_0 None
#   c-blosc2           pkgs/main/win-64::c-blosc2-2.8.0-hd77b12b_0 None
#   ca-certificates    pkgs/main/win-64::ca-certificates-2023.05.30-haa95532_0 None
#   certifi            pkgs/main/win-64::certifi-2023.5.7-py39haa95532_0 None
#   cffi               pkgs/main/win-64::cffi-1.15.1-py39h2bbff1b_3 None
#   cloudpickle        pkgs/main/win-64::cloudpickle-2.2.1-py39haa95532_0 None
#   colorama           pkgs/main/win-64::colorama-0.4.6-py39haa95532_0 None
#   colorcet           pkgs/main/win-64::colorcet-3.0.1-py39haa95532_0 None
#   comm               pkgs/main/win-64::comm-0.1.2-py39haa95532_0 None
#   comtypes           pkgs/main/win-64::comtypes-1.1.14-py39haa95532_0 None
#   conda-package-han~ pkgs/main/win-64::conda-package-handling-2.1.0-py39haa95532_0 None
#   conda-package-str~ pkgs/main/win-64::conda-package-streaming-0.8.0-py39haa95532_0 None
#   conda-repo-cli     pkgs/main/win-64::conda-repo-cli-1.0.41-py39haa95532_0 None
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py39h59b6b97_0 None
#   cryptography       pkgs/main/win-64::cryptography-39.0.1-py39h21b164f_0 None
#   curl               pkgs/main/win-64::curl-8.1.1-h2bbff1b_1 None
#   cython             pkgs/main/win-64::cython-0.29.35-py39hd77b12b_0 None
#   cytoolz            pkgs/main/win-64::cytoolz-0.12.0-py39h2bbff1b_0 None
#   daal4py            pkgs/main/win-64::daal4py-2023.1.1-py39h757b272_0 None
#   dal                pkgs/main/win-64::dal-2023.1.1-h59b6b97_48681 None
#   dask               pkgs/main/noarch::dask-2022.2.1-pyhd3eb1b0_0 None
#   dask-core          pkgs/main/noarch::dask-core-2022.2.1-pyhd3eb1b0_0 None
#   datashader         pkgs/main/win-64::datashader-0.15.1-py39haa95532_0 None
#   dill               pkgs/main/win-64::dill-0.3.6-py39haa95532_0 None
#   distributed        pkgs/main/noarch::distributed-2022.2.1-pyhd3eb1b0_0 None
#   docstring-to-mark~ pkgs/main/win-64::docstring-to-markdown-0.11-py39haa95532_0 None
#   exceptiongroup     pkgs/main/win-64::exceptiongroup-1.0.4-py39haa95532_0 None
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0 None
#   filelock           pkgs/main/win-64::filelock-3.9.0-py39haa95532_0 None
#   flake8             pkgs/main/win-64::flake8-6.0.0-py39haa95532_0 None
#   fsspec             pkgs/main/win-64::fsspec-2023.4.0-py39haa95532_0 None
#   future             pkgs/main/win-64::future-0.18.3-py39haa95532_0 None
#   gensim             pkgs/main/win-64::gensim-4.3.0-py39hd77b12b_0 None
#   giflib             pkgs/main/win-64::giflib-5.2.1-h8cc25b3_3 None
#   glib               pkgs/main/win-64::glib-2.69.1-h5dc1a3c_2 None
#   greenlet           pkgs/main/win-64::greenlet-2.0.1-py39hd77b12b_0 None
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0 None
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0 None
#   holoviews          pkgs/main/win-64::holoviews-1.16.2-py39haa95532_0 None
#   hvplot             pkgs/main/win-64::hvplot-0.8.4-py39haa95532_0 None
#   imagecodecs        pkgs/main/win-64::imagecodecs-2021.8.26-py39h319e4f4_2 None
#   imageio            pkgs/main/win-64::imageio-2.26.0-py39haa95532_0 None
#   importlib-metadata pkgs/main/win-64::importlib-metadata-6.0.0-py39haa95532_0 None
#   importlib_metadata pkgs/main/noarch::importlib_metadata-6.0.0-hd3eb1b0_0 None
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1 None
#   intake             pkgs/main/win-64::intake-0.6.8-py39haa95532_0 None
#   ipykernel          pkgs/main/win-64::ipykernel-6.19.2-py39hd4e2768_0 None
#   ipython            pkgs/main/win-64::ipython-8.12.0-py39haa95532_0 None
#   ipywidgets         pkgs/main/win-64::ipywidgets-8.0.4-py39haa95532_0 None
#   jaraco.classes     pkgs/main/noarch::jaraco.classes-3.2.1-pyhd3eb1b0_0 None
#   joblib             pkgs/main/win-64::joblib-1.2.0-py39haa95532_0 None
#   jpeg               pkgs/main/win-64::jpeg-9e-h2bbff1b_1 None
#   jsonschema         pkgs/main/win-64::jsonschema-4.17.3-py39haa95532_0 None
#   jupyter_client     pkgs/main/win-64::jupyter_client-8.1.0-py39haa95532_0 None
#   jupyter_console    pkgs/main/win-64::jupyter_console-6.6.3-py39haa95532_0 None
#   jupyter_core       pkgs/main/win-64::jupyter_core-5.3.0-py39haa95532_0 None
#   jupyterlab_widgets pkgs/main/win-64::jupyterlab_widgets-3.0.5-py39haa95532_0 None
#   jxrlib             pkgs/main/win-64::jxrlib-1.1-he774522_2 None
#   keyring            pkgs/main/win-64::keyring-23.13.1-py39haa95532_0 None
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py39hd77b12b_0 None
#   krb5               pkgs/main/win-64::krb5-1.19.4-h5b6d351_0 None
#   libarchive         pkgs/main/win-64::libarchive-3.6.2-h2033e3e_1 None
#   libclang           pkgs/main/win-64::libclang-14.0.6-default_hb5a9fac_1 None
#   libclang13         pkgs/main/win-64::libclang13-14.0.6-default_h8e68704_1 None
#   libcurl            pkgs/main/win-64::libcurl-8.1.1-h86230a5_1 None
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_0 None
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_0 None
#   liblief            pkgs/main/win-64::liblief-0.12.3-hd77b12b_0 None
#   libllvm14          pkgs/main/win-64::libllvm14-14.0.6-h4157e71_3 None
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1 None
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0 None
#   libssh2            pkgs/main/win-64::libssh2-1.10.0-hcd4344a_2 None
#   libtiff            pkgs/main/win-64::libtiff-4.5.0-h6c2663c_2 None
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0 None
#   libwebp            pkgs/main/win-64::libwebp-1.2.4-hbc33d0d_1 None
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_1 None
#   libxml2            pkgs/main/win-64::libxml2-2.10.3-h0ad7f3c_0 None
#   libxslt            pkgs/main/win-64::libxslt-1.1.37-h2bbff1b_0 None
#   linkify-it-py      pkgs/main/win-64::linkify-it-py-2.0.0-py39haa95532_0 None
#   llvmlite           pkgs/main/win-64::llvmlite-0.40.0-py39hf2fb9eb_0 None
#   lxml               pkgs/main/win-64::lxml-4.9.2-py39h2bbff1b_0 None
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_0 None
#   markdown           pkgs/main/win-64::markdown-3.4.1-py39haa95532_0 None
#   markdown-it-py     pkgs/main/win-64::markdown-it-py-2.2.0-py39haa95532_1 None
#   matplotlib         pkgs/main/win-64::matplotlib-3.7.1-py39haa95532_1 None
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.7.1-py39hf11a4ad_1 None
#   mccabe             pkgs/main/noarch::mccabe-0.7.0-pyhd3eb1b0_0 None
#   mdit-py-plugins    pkgs/main/win-64::mdit-py-plugins-0.3.0-py39haa95532_0 None
#   mdurl              pkgs/main/win-64::mdurl-0.1.0-py39haa95532_0 None
#   more-itertools     pkgs/main/noarch::more-itertools-8.12.0-pyhd3eb1b0_0 None
#   nbclassic          pkgs/main/win-64::nbclassic-0.5.5-py39haa95532_0 None
#   nbformat           pkgs/main/win-64::nbformat-5.7.0-py39haa95532_0 None
#   nest-asyncio       pkgs/main/win-64::nest-asyncio-1.5.6-py39haa95532_0 None
#   networkx           pkgs/main/win-64::networkx-2.8.4-py39haa95532_1 None
#   nltk               pkgs/main/win-64::nltk-3.8.1-py39haa95532_0 None
#   notebook           pkgs/main/win-64::notebook-6.5.4-py39haa95532_0 None
#   notebook-shim      pkgs/main/win-64::notebook-shim-0.2.2-py39haa95532_0 None
#   numba              pkgs/main/win-64::numba-0.57.0-py39h4ed8f06_0 None
#   numexpr            pkgs/main/win-64::numexpr-2.8.4-py39h5b0cc5e_0 None
#   numpydoc           pkgs/main/win-64::numpydoc-1.5.0-py39haa95532_0 None
#   openssl            pkgs/main/win-64::openssl-1.1.1u-h2bbff1b_0 None
#   packaging          pkgs/main/win-64::packaging-23.0-py39haa95532_0 None
#   panel              pkgs/main/win-64::panel-1.1.0-py39haa95532_0 None
#   param              pkgs/main/win-64::param-1.13.0-py39haa95532_0 None
#   pathspec           pkgs/main/win-64::pathspec-0.10.3-py39haa95532_0 None
#   patsy              pkgs/main/win-64::patsy-0.5.3-py39haa95532_0 None
#   pcre               pkgs/main/win-64::pcre-8.45-hd77b12b_0 None
#   pillow             pkgs/main/win-64::pillow-9.4.0-py39hd77b12b_0 None
#   pip                pkgs/main/win-64::pip-23.1.2-py39haa95532_0 None
#   pkginfo            pkgs/main/win-64::pkginfo-1.9.6-py39haa95532_0 None
#   ply                pkgs/main/win-64::ply-3.11-py39haa95532_0 None
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0 None
#   prompt-toolkit     pkgs/main/win-64::prompt-toolkit-3.0.36-py39haa95532_0 None
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.36-hd3eb1b0_0 None
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0 None
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-pyhd3eb1b0_1 None
#   py-lief            pkgs/main/win-64::py-lief-0.12.3-py39hd77b12b_0 None
#   pycodestyle        pkgs/main/win-64::pycodestyle-2.10.0-py39haa95532_0 None
#   pycosat            pkgs/main/win-64::pycosat-0.6.4-py39h2bbff1b_0 None
#   pyct               pkgs/main/win-64::pyct-0.5.0-py39haa95532_0 None
#   pycurl             pkgs/main/win-64::pycurl-7.45.2-py39hcd4344a_0 None
#   pydocstyle         pkgs/main/win-64::pydocstyle-6.3.0-py39haa95532_0 None
#   pyflakes           pkgs/main/win-64::pyflakes-3.0.1-py39haa95532_0 None
#   pygments           pkgs/main/win-64::pygments-2.15.1-py39haa95532_1 None
#   pylint             pkgs/main/win-64::pylint-2.16.2-py39haa95532_0 None
#   pylint-venv        pkgs/main/win-64::pylint-venv-2.3.0-py39haa95532_0 None
#   pyopenssl          pkgs/main/win-64::pyopenssl-23.0.0-py39haa95532_0 None
#   pyqt               pkgs/main/win-64::pyqt-5.15.7-py39hd77b12b_0 None
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.11.0-py39hd77b12b_0 None
#   pyqtwebengine      pkgs/main/win-64::pyqtwebengine-5.15.7-py39hd77b12b_0 None
#   pytables           pkgs/main/win-64::pytables-3.8.0-py39ha4dc190_2 None
#   pytest             pkgs/main/win-64::pytest-7.3.1-py39haa95532_0 None
#   python-lmdb        pkgs/main/win-64::python-lmdb-1.4.1-py39hd77b12b_0 None
#   python-lsp-black   pkgs/main/win-64::python-lsp-black-1.2.1-py39haa95532_0 None
#   python-lsp-server  pkgs/main/win-64::python-lsp-server-1.7.2-py39haa95532_0 None
#   python-snappy      pkgs/main/win-64::python-snappy-0.6.1-py39hd77b12b_0 None
#   pytoolconfig       pkgs/main/win-64::pytoolconfig-1.2.5-py39haa95532_1 None
#   pytz               pkgs/main/win-64::pytz-2022.7-py39haa95532_0 None
#   pyviz_comms        pkgs/main/win-64::pyviz_comms-2.3.0-py39haa95532_0 None
#   pywavelets         pkgs/main/win-64::pywavelets-1.4.1-py39h2bbff1b_0 None
#   pywin32            pkgs/main/win-64::pywin32-305-py39h2bbff1b_0 None
#   pywinpty           pkgs/main/win-64::pywinpty-2.0.10-py39h5da7b33_0 None
#   pyzmq              pkgs/main/win-64::pyzmq-25.1.0-py39hd77b12b_0 None
#   qstylizer          pkgs/main/win-64::qstylizer-0.2.2-py39haa95532_0 None
#   qt                 pkgs/main/win-64::qt-5.15.7-haa95532_0 None
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-he8e5bd7_8 None
#   qt-webengine       pkgs/main/win-64::qt-webengine-5.15.9-hb9a9bb5_5 None
#   qtawesome          pkgs/main/win-64::qtawesome-1.2.2-py39haa95532_0 None
#   qtconsole          pkgs/main/win-64::qtconsole-5.4.2-py39haa95532_0 None
#   qtwebkit           pkgs/main/win-64::qtwebkit-5.212-h2bbfb41_5 None
#   requests           pkgs/main/win-64::requests-2.29.0-py39haa95532_0 None
#   requests-toolbelt  pkgs/main/noarch::requests-toolbelt-0.9.1-pyhd3eb1b0_0 None
#   rope               pkgs/main/win-64::rope-1.7.0-py39haa95532_0 None
#   rtree              pkgs/main/win-64::rtree-1.0.1-py39h2eaa2aa_0 None
#   scikit-image       pkgs/main/win-64::scikit-image-0.19.3-py39hd77b12b_1 None
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.2.2-py39hd77b12b_1 None
#   scikit-learn-inte~ pkgs/main/win-64::scikit-learn-intelex-2023.1.1-py39haa95532_0 None
#   scipy              pkgs/main/win-64::scipy-1.10.1-py39h321e85e_0 None
#   scrapy             pkgs/main/win-64::scrapy-2.8.0-py39haa95532_0 None
#   seaborn            pkgs/main/win-64::seaborn-0.12.2-py39haa95532_0 None
#   setuptools         pkgs/main/win-64::setuptools-67.8.0-py39haa95532_0 None
#   sip                pkgs/main/win-64::sip-6.6.2-py39hd77b12b_0 None
#   soupsieve          pkgs/main/win-64::soupsieve-2.4-py39haa95532_0 None
#   spyder             pkgs/main/win-64::spyder-5.4.3-py39haa95532_1 None
#   spyder-kernels     pkgs/main/win-64::spyder-kernels-2.4.3-py39haa95532_0 None
#   sqlite             pkgs/main/win-64::sqlite-3.41.2-h2bbff1b_0 None
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0 None
#   statsmodels        pkgs/main/win-64::statsmodels-0.13.5-py39h080aedc_1 None
#   sympy              pkgs/main/win-64::sympy-1.11.1-py39haa95532_0 None
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0 None
#   tbb4py             pkgs/main/win-64::tbb4py-2021.8.0-py39h59b6b97_0 None
#   tenacity           pkgs/main/win-64::tenacity-8.2.2-py39haa95532_0 None
#   terminado          pkgs/main/win-64::terminado-0.17.1-py39haa95532_0 None
#   tinycss2           pkgs/main/win-64::tinycss2-1.2.1-py39haa95532_0 None
#   toolz              pkgs/main/win-64::toolz-0.12.0-py39haa95532_0 None
#   tornado            pkgs/main/win-64::tornado-6.2-py39h2bbff1b_0 None
#   tqdm               pkgs/main/win-64::tqdm-4.65.0-py39hd4e2768_0 None
#   traitlets          pkgs/main/win-64::traitlets-5.7.1-py39haa95532_0 None
#   twisted            pkgs/main/win-64::twisted-22.10.0-py39h2bbff1b_0 None
#   typing-extensions  pkgs/main/win-64::typing-extensions-4.6.3-py39haa95532_0 None
#   typing_extensions  pkgs/main/win-64::typing_extensions-4.6.3-py39haa95532_0 None
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0 None
#   uc-micro-py        pkgs/main/win-64::uc-micro-py-1.0.1-py39haa95532_0 None
#   urllib3            pkgs/main/win-64::urllib3-1.26.16-py39haa95532_0 None
#   whatthepatch       pkgs/main/win-64::whatthepatch-1.0.2-py39haa95532_0 None
#   wheel              pkgs/main/win-64::wheel-0.38.4-py39haa95532_0 None
#   widgetsnbextension pkgs/main/win-64::widgetsnbextension-4.0.5-py39haa95532_0 None
#   xarray             pkgs/main/win-64::xarray-2023.6.0-py39haa95532_0 None
#   xlrd               pkgs/main/noarch::xlrd-2.0.1-pyhd3eb1b0_1 None
#   xlsxwriter         pkgs/main/win-64::xlsxwriter-3.1.1-py39haa95532_0 None
#   xyzservices        pkgs/main/win-64::xyzservices-2022.9.0-py39haa95532_1 None
#   xz                 pkgs/main/win-64::xz-5.4.2-h8cc25b3_0 None
#   zict               pkgs/main/win-64::zict-2.2.0-py39haa95532_0 None
#   zipp               pkgs/main/win-64::zipp-3.11.0-py39haa95532_0 None
#   zlib-ng            pkgs/main/win-64::zlib-ng-2.0.7-h2bbff1b_0 None
#   zstandard          pkgs/main/win-64::zstandard-0.19.0-py39h2bbff1b_0 None
#   zstd               pkgs/main/win-64::zstd-1.5.5-hd43e919_0 None
#
#
#
# Downloading and Extracting Packages
#
# distributed-2022.2.1 | 659 KB    |            |   0%
# distributed-2022.2.1 | 659 KB    | 2          |   2%
# distributed-2022.2.1 | 659 KB    | ####8      |  49%
# distributed-2022.2.1 | 659 KB    | ########## | 100%
# distributed-2022.2.1 | 659 KB    | ########## | 100%
#
# dask-2022.2.1        | 5 KB      |            |   0%
# dask-2022.2.1        | 5 KB      | ########## | 100%
#
# dask-core-2022.2.1   | 747 KB    |            |   0%
# dask-core-2022.2.1   | 747 KB    | 6          |   6%
# dask-core-2022.2.1   | 747 KB    | ########## | 100%
# dask-core-2022.2.1   | 747 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::alabaster==0.7.12=pyhd3eb1b0_0
#   - defaults/win-64::anaconda==2022.10=py310_0
#   - defaults/win-64::anaconda-navigator==2.3.2=py39haa95532_0
#   - defaults/win-64::anaconda-project==0.11.1=py39haa95532_0
#   - defaults/win-64::anyio==3.5.0=py39haa95532_0
#   - defaults/noarch::appdirs==1.4.4=pyhd3eb1b0_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/win-64::argon2-cffi-bindings==21.2.0=py39h2bbff1b_0
#   - defaults/win-64::astropy==5.1=py39h080aedc_0
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/noarch::automat==20.2.0=py_0
#   - defaults/noarch::autopep8==1.6.0=pyhd3eb1b0_1
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/noarch::backports==1.1=pyhd3eb1b0_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/noarch::backports.tempfile==1.0=pyhd3eb1b0_1
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/win-64::bcrypt==3.2.0=py39h2bbff1b_1
#   - defaults/noarch::binaryornot==0.4.4=pyhd3eb1b0_1
#   - defaults/win-64::bitarray==2.5.1=py39h2bbff1b_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_1
#   - defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0
#   - defaults/win-64::boto3==1.24.28=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.5=py39h080aedc_0
#   - defaults/win-64::brotlipy==0.7.0=py39h2bbff1b_1003
#   - defaults/win-64::chardet==4.0.0=py39haa95532_1003
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/win-64::click==8.0.4=py39haa95532_0
#   - defaults/win-64::clyent==1.2.2=py39haa95532_1
#   - defaults/win-64::conda==22.9.0=py39haa95532_0
#   - defaults/win-64::conda-build==3.22.0=py39haa95532_0
#   - defaults/win-64::conda-content-trust==0.1.3=py39haa95532_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/win-64::console_shortcut==0.1.1=4
#   - defaults/noarch::constantly==15.1.0=pyh2b92418_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/noarch::cssselect==1.1.0=pyhd3eb1b0_0
#   - defaults/noarch::cycler==0.11.0=pyhd3eb1b0_0
#   - defaults/noarch::dataclasses==0.8=pyh6d0b6a4_7
#   - defaults/win-64::datashape==0.5.4=py39haa95532_1
#   - defaults/win-64::debugpy==1.5.1=py39hd77b12b_0
#   - defaults/noarch::decorator==5.1.1=pyhd3eb1b0_0
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/noarch::diff-match-patch==20200713=pyhd3eb1b0_0
#   - defaults/win-64::docutils==0.18.1=py39haa95532_3
#   - defaults/win-64::entrypoints==0.4=py39haa95532_0
#   - defaults/win-64::et_xmlfile==1.1.0=py39haa95532_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::fonttools==4.25.0=pyhd3eb1b0_0
#   - defaults/win-64::freetype==2.12.1=ha860e81_0
#   - defaults/noarch::glob2==0.7=pyhd3eb1b0_0
#   - defaults/win-64::h5py==3.7.0=py39h3de5c98_0
#   - defaults/noarch::heapdict==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::hyperlink==21.0.0=pyhd3eb1b0_0
#   - defaults/win-64::idna==3.4=py39haa95532_0
#   - defaults/win-64::imagesize==1.4.1=py39haa95532_0
#   - defaults/noarch::incremental==21.3.0=pyhd3eb1b0_0
#   - defaults/win-64::inflection==0.5.1=py39haa95532_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/noarch::intervaltree==3.1.0=pyhd3eb1b0_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/noarch::isort==5.9.3=pyhd3eb1b0_0
#   - defaults/noarch::itemadapter==0.3.0=pyhd3eb1b0_0
#   - defaults/noarch::itemloaders==1.0.4=pyhd3eb1b0_1
#   - defaults/noarch::itsdangerous==2.0.1=pyhd3eb1b0_0
#   - defaults/noarch::jdcal==1.4.1=pyhd3eb1b0_0
#   - defaults/win-64::jedi==0.18.1=py39haa95532_1
#   - defaults/win-64::jellyfish==0.9.0=py39h2bbff1b_0
#   - defaults/noarch::jinja2==2.11.3=pyhd3eb1b0_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/noarch::jmespath==0.10.0=pyhd3eb1b0_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_8
#   - defaults/win-64::jupyterlab==3.4.4=py39haa95532_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/win-64::jupyter_server==1.18.1=py39haa95532_0
#   - defaults/win-64::lazy-object-proxy==1.6.0=py39h2bbff1b_0
#   - defaults/win-64::lcms2==2.12=h83e58a3_0
#   - defaults/win-64::locket==1.0.0=py39haa95532_0
#   - defaults/win-64::markupsafe==2.0.1=py39h2bbff1b_0
#   - defaults/win-64::matplotlib-inline==0.1.6=py39haa95532_0
#   - defaults/win-64::menuinst==1.4.19=py39h59b6b97_0
#   - defaults/win-64::mistune==0.8.4=py39h2bbff1b_1000
#   - defaults/win-64::mkl-service==2.4.0=py39h2bbff1b_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/win-64::mpmath==1.2.1=py39haa95532_0
#   - defaults/win-64::msgpack-python==1.0.3=py39h59b6b97_0
#   - defaults/win-64::multipledispatch==0.6.0=py39haa95532_0
#   - defaults/noarch::munkres==1.1.4=py_0
#   - defaults/win-64::mypy_extensions==0.4.3=py39haa95532_1
#   - defaults/win-64::navigator-updater==0.3.0=py39haa95532_0
#   - defaults/win-64::nbclient==0.5.13=py39haa95532_0
#   - defaults/win-64::nbconvert==6.4.4=py39haa95532_0
#   - defaults/noarch::nose==1.3.7=pyhd3eb1b0_1008
#   - defaults/win-64::numpy==1.21.5=py39h7a0a035_3
#   - defaults/win-64::numpy-base==1.21.5=py39hca35cd5_3
#   - defaults/noarch::olefile==0.46=pyhd3eb1b0_0
#   - defaults/win-64::openjpeg==2.4.0=h4fc8c34_0
#   - defaults/win-64::openpyxl==3.0.10=py39h2bbff1b_0
#   - defaults/win-64::pandas==1.4.4=py39hd77b12b_0
#   - defaults/noarch::pandocfilters==1.5.0=pyhd3eb1b0_0
#   - defaults/noarch::paramiko==2.8.1=pyhd3eb1b0_0
#   - defaults/win-64::parsel==1.6.0=py39haa95532_0
#   - defaults/noarch::parso==0.8.3=pyhd3eb1b0_0
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_1
#   - defaults/noarch::pathlib==1.0.1=pyhd3eb1b0_1
#   - defaults/win-64::pep8==1.7.1=py39haa95532_1
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/win-64::platformdirs==2.5.2=py39haa95532_0
#   - defaults/win-64::plotly==5.9.0=py39haa95532_0
#   - defaults/win-64::pluggy==1.0.0=py39haa95532_1
#   - defaults/win-64::powershell_shortcut==0.0.1=3
#   - defaults/noarch::poyo==0.5.0=pyhd3eb1b0_0
#   - defaults/win-64::prometheus_client==0.14.1=py39haa95532_0
#   - defaults/noarch::protego==0.1.16=py_0
#   - defaults/win-64::psutil==5.9.0=py39h2bbff1b_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::py==1.11.0=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1==0.4.8=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1-modules==0.2.8=py_0
#   - defaults/noarch::pycparser==2.21=pyhd3eb1b0_0
#   - defaults/win-64::pydispatcher==2.0.5=py39haa95532_2
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/win-64::pyjwt==2.4.0=py39haa95532_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::pynacl==1.5.0=py39h8cc25b3_0
#   - defaults/win-64::pyodbc==4.0.34=py39hd77b12b_0
#   - defaults/win-64::pyparsing==3.0.9=py39haa95532_0
#   - defaults/win-64::pyrsistent==0.18.0=py39h196d8e1_0
#   - defaults/win-64::pysocks==1.7.1=py39haa95532_0
#   - defaults/win-64::python==3.9.13=h6244533_1
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/win-64::python-fastjsonschema==2.16.2=py39haa95532_0
#   - defaults/noarch::python-libarchive-c==2.9=pyhd3eb1b0_1
#   - defaults/noarch::python-lsp-jsonrpc==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::python-slugify==5.0.2=pyhd3eb1b0_0
#   - defaults/win-64::pywin32-ctypes==0.2.0=py39haa95532_1000
#   - defaults/win-64::pyyaml==6.0=py39h2bbff1b_1
#   - defaults/noarch::qdarkstyle==3.0.2=pyhd3eb1b0_0
#   - defaults/win-64::qtpy==2.2.0=py39haa95532_0
#   - defaults/win-64::queuelib==1.5.0=py39haa95532_0
#   - defaults/win-64::regex==2022.7.9=py39h2bbff1b_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/win-64::ruamel_yaml==0.15.100=py39h2bbff1b_0
#   - defaults/win-64::s3transfer==0.6.0=py39haa95532_0
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/noarch::service_identity==18.1.0=pyhd3eb1b0_1
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_1
#   - defaults/win-64::smart_open==5.2.1=py39haa95532_0
#   - defaults/win-64::sniffio==1.2.0=py39haa95532_1
#   - defaults/noarch::snowballstemmer==2.2.0=pyhd3eb1b0_0
#   - defaults/noarch::sortedcollections==2.1.0=pyhd3eb1b0_0
#   - defaults/noarch::sortedcontainers==2.4.0=pyhd3eb1b0_0
#   - defaults/win-64::sphinx==5.0.2=py39haa95532_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==2.0.0=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=pyhd3eb1b0_0
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.5=pyhd3eb1b0_0
#   - defaults/win-64::sqlalchemy==1.4.39=py39h2bbff1b_0
#   - defaults/win-64::tabulate==0.8.10=py39haa95532_0
#   - defaults/noarch::tblib==1.7.0=pyhd3eb1b0_0
#   - defaults/win-64::testpath==0.6.0=py39haa95532_0
#   - defaults/noarch::text-unidecode==1.3=pyhd3eb1b0_0
#   - defaults/noarch::textdistance==4.2.1=pyhd3eb1b0_0
#   - defaults/noarch::threadpoolctl==2.2.0=pyh0d69192_0
#   - defaults/noarch::three-merge==0.1.1=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/win-64::tomli==2.0.1=py39haa95532_0
#   - defaults/win-64::tomlkit==0.11.1=py39haa95532_0
#   - defaults/win-64::twisted-iocpsupport==1.0.2=py39h2bbff1b_0
#   - defaults/win-64::ujson==5.4.0=py39hd77b12b_0
#   - defaults/noarch::unidecode==1.2.0=pyhd3eb1b0_0
#   - defaults/noarch::w3lib==1.21.0=pyhd3eb1b0_0
#   - defaults/win-64::watchdog==2.1.6=py39haa95532_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/win-64::webencodings==0.5.1=py39haa95532_1
#   - defaults/win-64::websocket-client==0.58.0=py39haa95532_4
#   - defaults/noarch::werkzeug==2.0.3=pyhd3eb1b0_0
#   - defaults/win-64::win_inet_pton==1.1.0=py39haa95532_0
#   - defaults/win-64::win_unicode_console==0.5=py39haa95532_0
#   - defaults/win-64::wrapt==1.14.1=py39h2bbff1b_0
#   - defaults/win-64::xlwings==0.27.15=py39haa95532_0
#   - defaults/noarch::yapf==0.31.0=pyhd3eb1b0_0
#   - defaults/win-64::zope==1.0=py39haa95532_1
#   - defaults/win-64::zope.interface==5.4.0=py39h2bbff1b_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# RemoveError: 'conda-package-handling' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'pycosat' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'pyopenssl' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'setuptools' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'toolz' is a dependency of conda and cannot be removed from
# conda's operating environment.

# %%
pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (from imbalanced-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jrgar\anaconda3\envs\pythondata\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SMOTEENN
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement SMOTEENN (from versions: none)
# ERROR: No matching distribution found for SMOTEENN

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from imblearn.metrics import classification_report_imbalanced
from imblearn.combine import SMOTEENN

# %%
credit_df = pd.read_csv(r'C:\Users\Columbia bootcamp\Credit_Risk_Analysis\Starter_Code\LoanStats_2019Q1.csv')
credit_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id                                               member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title                                emp_length home_ownership annual_inc verification_status issue_d  loan_status pymnt_plan url desc purpose            title                   zip_code addr_state dti   delinq_2yrs earliest_cr_line inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_actv_bc_tl num_actv_rev_tl num_bc_sats num_bc_tl num_il_tl num_op_rev_tl num_rev_accts num_rev_tl_bal_gt_0 num_sats num_tl_120dpd_2m num_tl_30dpd num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit total_il_high_credit_limit revol_bal_joint sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog hardship_flag hardship_type hardship_reason hardship_status deferral_term hardship_amount hardship_start_date hardship_end_date payment_plan_start_date hardship_length hardship_dpd hardship_loan_status orig_projected_additional_accrued_interest hardship_payoff_balance_amount hardship_last_payment_amount debt_settlement_flag debt_settlement_flag_date settlement_status settlement_date settlement_amount settlement_percentage                                    settlement_term
# NaN                                              NaN       20000     20000       20000            60 months  17.19%  499.1       C     C5        Front desk supervisor                    6 years    RENT           47000      Source Verified     Mar-2019 Issued      n          NaN NaN  debt_consolidation Debt consolidation      958xx    CA         14.02 0           Sep-2006         1              50                     NaN                    15       0       10687     19.7%      53        w                   20000.00  20000.00      0.0         0.00            0.00            0.00          0.0                0.0        0.0                     NaN          0.0             Apr-2019     Apr-2019           0                          50                          1           Individual       NaN              NaN       NaN                       0              0            31546       3           2           1           2           10                 20859        97      4           9           5909       42       54300            6      1           3            11                   2103        23647          30      0                        0           150                100                  1                     1              0        5                    NaN                      3                     50                             3                     3              4               8           19        19        13            33            4                   15       0                0            0                  5                  98             12.5             0                    0         75824           31546             33800          21524                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#                                                            21225     21225       21225            60 months  14.74%  502.05      C     C2        ceo                                      10+ years  MORTGAGE       225000     Not Verified        Mar-2019 Issued      n          NaN NaN  credit_card        Credit card refinancing 956xx    CA         16.8  0           Sep-1994         2              NaN                    110                    14       1       95868     87.7%      22        w                   21225.00  21225.00      0.0         0.00            0.00            0.00          0.0                0.0        0.0                     NaN          0.0             Apr-2019     Apr-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            694793      1           5           2           4           3                  113558       76      0           1           17353      84       109300           1      0           4            5                    49628       12635          76.4    0                        0           126                294                  24                    3              4        30                   NaN                      1                     NaN                            0                     4              6               4           4         11        7             7             6                   14       0                0            0                  2                  100            50               1                    0         747075          209426            53500          128175                     NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#                                                            5000      5000        5000             36 months  17.97%  180.69      D     D1        NaN                                      NaN        MORTGAGE       62000      Not Verified        Mar-2019 Issued      n          NaN NaN  home_improvement   Home improvement        320xx    FL         19.82 1           Nov-1987         0              4                      NaN                    8        0       7285      77.5%      18        w                   5000.00   5000.00       0.0         0.00            0.00            0.00          0.0                0.0        0.0                     NaN          0.0             Apr-2019     Apr-2019           0                          4                           1           Individual       NaN              NaN       NaN                       0              0            206639      0           1           0           0           33                 24330        NaN     1           3           2318       78       9400             0      0           0            3                    25830       2115           77.5    0                        0           187                376                  9                     9              2        9                    NaN                      NaN                   4                              3                     6              6               6           6         7         6             9             6                   8        0                0            1                  1                  66.7           50               0                    0         255738          31615             9400           39938                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#                                                            20000     20000       20000            36 months   8.19%  628.49      A     A4        Executive Director of Guardian Advantage 1 year     MORTGAGE       200000     Not Verified        Mar-2019 Issued      n          NaN NaN  credit_card        Credit card refinancing 190xx    PA         22.66 1           Oct-2001         0              18                     NaN                    20       0       20984     32.1%      49        w                   20000.00  20000.00      0.0         0.00            0.00            0.00          0.0                0.0        0.0                     NaN          0.0             Apr-2019     Apr-2019           0                          48                          1           Individual       NaN              NaN       NaN                       0              0            326678      2           5           1           3           4                  63760        61      2           3           5097       50       64400            1      5           0            6                    17194       30437          38.4    0                        0           162                209                  2                     2              1        2                    18                       21                    18                             1                     7              9               9           15        20        14            27            9                   20       0                0            0                  3                  95.7           22.2             0                    0         448069          84744             49400          105180                     NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#                                                            16000     16000       16000            36 months  16.14%  563.62      C     C4        Estimator/Supervisor                     10+ years  MORTGAGE       32000.0    Source Verified     Jan-2019 Current     n          NaN NaN  debt_consolidation Debt consolidation      925xx    CA         20.89 0           Dec-2010         0              35.0                   117.0                  13       1       17066.0   49.9%      15        f                   14940.62  14940.62      1676.51     1676.51         1059.38         617.13        0.0                0.0        0.0                     Apr-2019     563.62          May-2019     Apr-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            17066.0     1           0           0           0           55.0               0            NaN     3           3           2353       50.0     34200            0      0           1            3                    1313        6446.0         60.7    0                        0           55.0               96                   1                     1              0        1.0                  35.0                     12.0                  35.0                           0                     7              8               8           8         1         13            14            8                   13       0.0              0            0                  3                  93.3           37.5             1                    0         34200           17066.0           16400          0                          NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#                                                                                                   60 months  11.31%  350.36      B     B3        MATERIAL HANDLER                         5 years    MORTGAGE       72000.0    Verified            Jan-2019 Current     n          NaN NaN  debt_consolidation Debt consolidation      850xx    AZ         7.02  2           Sep-2005         0              8.0                    64.0                   12       1       11882     37.1%      39        w                   15395.66  15395.66      1041.03     1041.03         604.34          436.69        0.0                0.0        0.0                     Apr-2019     350.36          May-2019     Apr-2019           0                          8.0                         1           Individual       NaN              NaN       NaN                       0              0            225413.0    0           2           0           0           28.0               62953.0      79.0    0           0           5568       45.0     32000            2      2           4            1                    18784.0     11705.0        49.1    2                        0           159.0              129                  25                    24             3        25.0                 NaN                      1.0                   9.0                            2                     4              5               5           9         20        9             16            5                   12       0.0              0            2                  0                  94.3           0.0              1                    0         251486.0        74835.0           23000          63090                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#                                                            29250     29250       29250            60 months  18.94%  757.8       D     D2        sr register csa                          7 years    MORTGAGE       65000.0    Verified            Jan-2019 Current     n          NaN NaN  debt_consolidation Debt consolidation      774xx    TX         29.52 0           Jan-2011         0              NaN                    NaN                    20       0       38465.0   69%        22        w                   28347.49  28347.49      2211.84     2211.84         902.51          1309.33       0.0                0.0        0.0                     Apr-2019     757.8           May-2019     Apr-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            204764      0           1           0           1           17.0               20323        79.0    1           3           13874      69.0     55505.0          0      0           0            4                    10238       2985.0         87.0    0                        0           78.0               95                   7                     7              1        19.0                 NaN                      13.0                  NaN                            0                     13             18              13          13        3         18            18            18                  20       NaN              0            0                  1                  100.0          76.9             0                    0         237833.0        58788             38800          25728.0                    NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# Total amount funded in policy code 1: 1928448350 NaN       NaN       NaN         NaN             NaN        NaN      NaN         NaN   NaN       NaN                                      NaN        NaN            NaN        NaN                 NaN      NaN         NaN        NaN NaN  NaN                NaN                     NaN      NaN        NaN   NaN         NaN              NaN            NaN                    NaN                    NaN      NaN     NaN       NaN        NaN       NaN                 NaN       NaN           NaN         NaN             NaN             NaN           NaN                NaN        NaN                     NaN          NaN             NaN          NaN                NaN                        NaN                         NaN         NaN              NaN              NaN       NaN                       NaN            NaN          NaN         NaN         NaN         NaN         NaN         NaN                NaN          NaN     NaN         NaN         NaN        NaN      NaN              NaN    NaN         NaN          NaN                  NaN         NaN            NaN     NaN                      NaN         NaN                NaN                  NaN                   NaN            NaN      NaN                  NaN                      NaN                   NaN                            NaN                   NaN            NaN             NaN         NaN       NaN       NaN           NaN           NaN                 NaN      NaN              NaN          NaN                NaN                NaN            NaN              NaN                  NaN       NaN             NaN               NaN            NaN                        NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 NaN           NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          NaN                  NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# Total amount funded in policy code 2: 799382986  NaN       NaN       NaN         NaN             NaN        NaN      NaN         NaN   NaN       NaN                                      NaN        NaN            NaN        NaN                 NaN      NaN         NaN        NaN NaN  NaN                NaN                     NaN      NaN        NaN   NaN         NaN              NaN            NaN                    NaN                    NaN      NaN     NaN       NaN        NaN       NaN                 NaN       NaN           NaN         NaN             NaN             NaN           NaN                NaN        NaN                     NaN          NaN             NaN          NaN                NaN                        NaN                         NaN         NaN              NaN              NaN       NaN                       NaN            NaN          NaN         NaN         NaN         NaN         NaN         NaN                NaN          NaN     NaN         NaN         NaN        NaN      NaN              NaN    NaN         NaN          NaN                  NaN         NaN            NaN     NaN                      NaN         NaN                NaN                  NaN                   NaN            NaN      NaN                  NaN                      NaN                   NaN                            NaN                   NaN            NaN             NaN         NaN       NaN       NaN           NaN           NaN                 NaN      NaN              NaN          NaN                NaN                NaN            NaN              NaN                  NaN       NaN             NaN               NaN            NaN                        NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 NaN           NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          NaN                  NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#
# [115678 rows x 1 columns]

# %%
columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

features = columns + target

# Print the combined list
print(features)
# Out:
# ['loan_amnt', 'int_rate', 'installment', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'next_pymnt_d', 'collections_12_mths_ex_med', 'policy_code', 'application_type', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'hardship_flag', 'debt_settlement_flag', 'loan_status']

# %%
# Check if each column exists in the DataFrame
#filtered_columns = [col for col in credit_df.columns if col in columns]
filtered_columns = [col for col in columns if col in credit_df.columns]

# Print the filtered columns
print(filtered_columns)
# Out:
# []

# %%
# Check if any columns are left after filtering
if len(filtered_columns) == 0:
    print("No common columns found between the list and the DataFrame.")
else:
    # Create the training variables by converting the string values into numerical ones using the get_dummies() method
    credit_df = pd.get_dummies(df_selected[filtered_columns])

    # Create the target variable
    target_variable = df_selected[target].values.flatten()

    # Check the balance of the target variable
    target_balance = pd.Series(target_variable).value_counts()
    imbalance_ratio = target_balance[1] / target_balance[0]

    # Print the balance information
    print("Target Variable Balance:")
    print(target_balance)
    print("Imbalance Ratio: {:.2f}".format(imbalance_ratio))
# Out:
# No common columns found between the list and the DataFrame.

# %%
# Filter the columns that exist in the DataFrame
filtered_columns = [col for col in columns if col in credit_df.columns]

# Create the training variables by converting the string values into numerical ones using the get_dummies() method
credit_df = pd.get_dummies(credit_df[filtered_columns])

# Create the target variable
target_variable = credit_df[target].values.flatten()

# Check the balance of the target variable
target_balance = pd.Series(target_variable).value_counts()
imbalance_ratio = target_balance[1] / target_balance[0]

# Print the balance information
print("Target Variable Balance:")
print(target_balance)
print("Imbalance Ratio: {:.2f}".format(imbalance_ratio))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32988\489320480.py in <module>
#       3
#       4 # Create the training variables by converting the string values into numerical ones using the get_dummies() method
# ----> 5 credit_df = pd.get_dummies(credit_df[filtered_columns])
#       6
#       7 # Create the target variable
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     944             )
#     945             with_dummies.append(dummy)
# --> 946         result = concat(with_dummies, axis=1)
#     947     else:
#     948         result = _get_dummies_1d(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# Load the data
file_path = Path(r'C:\Users\Columbia bootcamp\Credit_Risk_Analysis\Starter_Code\LoanStats_2019Q1.csv')
df = credit_df
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# Remove the `Issued` loan status
#issued_mask = df['loan_status'] != 'Issued'
#df = df.loc[issued_mask]

# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100

df_selected = df
# Convert the tar# Convert the target column values to low_risk and high_risk based on their values
df_selected['loan_status'] = df_selected['loan_status'].map({'Fully Paid': 'low_risk', 'Charged Off': 'high_risk'})

x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df_selected.head()

# %%
# Create our features
df_selected = pd.get_dummies(df_selected.drop(target, axis=1))

# Create our target
target_variable = df_selected[target].values.flatten()
target_balance = pd.Series(target_variable).value_counts()
imbalance_ratio = target_balance[1] / target_balance[0]

# %%
df_selected.describe()

# %%
# Check the balance of our target values
df_selected['loan_status'].value_counts()

# %%
# Resample the training data with the RandomOversampler

print("Before Random Oversampling:")
print(df_selected['loan_status'].value_counts())


random_oversampler = RandomOverSampler(random_state=1)

# Resample the training data
X_resampled, y_resampled = random_oversampler.fit_resample(df_selected.drop('loan_status', axis=1), df_selected['loan_status'])


print("After Random Oversampling:")
print(pd.Series(y_resampled).value_counts())

# %%
# Train the Logistic Regression model using the resampled data

training_data = df_selected
training_data = x
X = training_data.drop('loan_status', axis=1)
y = training_data['loan_status']

logreg = LogisticRegression(random_state=1)

logreg.fit(X_resampled, y_resampled)

# %%
# Calculated the balanced accuracy score
y_pred = logreg.predict(X_test)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print("Balanced Accuracy Score:", balanced_accuracy)

# %%
# Display the confusion matrix

confusion_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_matrix)

# %%
# Print the imbalanced classification report
classification_report_imbalanced = classification_report(y_test, y_pred)
print("Classification Report (Imbalanced):")
print(classification_report_imbalanced)

# %%
# Resample the training data with SMOTE
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=1)

X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# Train the Logistic Regression model using the resampled data

logreg = LogisticRegression(random_state=1)
logreg.fit(X_resampled, y_resampled)

# %%
# Calculated the balanced accuracy score
y_pred = logreg.predict(X_test)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

print("Balanced Accuracy Score:", balanced_accuracy)

# %%
# Display the confusion matrix
y_pred = logreg.predict(X_test)

# Calculate the confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion_matrix)

# %%
# Print the imbalanced classification report
print("Imbalanced Classification Report:")
print(classification_report_imbalanced(y_test, y_pred))

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
from imblearn.under_sampling import ClusterCentroids

# %%
cluster_centroids = ClusterCentroids(random_state=1)
X_resampled, y_resampled = cluster_centroids.fit_resample(X, y)
print("After ClusterCentroids Resampling:")
print(pd.Series(y_resampled).value_counts())

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(random_state=1)
logreg = LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = logreg.predict(X_test)
balanced_acc = balanced_accuracy_score(y_test, y_pred)
print("Balanced Accuracy Score:", balanced_acc)

# %%
# Display the confusion matrix
y_pred = logreg.predict(X_test)
confusion_matrix = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion_matrix)

# %%
# Print the imbalanced classification report

print("Imbalanced Classification Report:")
print(classification_report_imbalanced(y_test, y_pred))

# %%
# Resample the training data with SMOTEENN
smoteenn = SMOTEENN(random_state=1)
X_resampled, y_resampled = smoteenn.fit_resample(X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
logreg = LogisticRegression(random_state=1)
logreg.fit(X_resampled, y_resampled)

# %%
# Calculated the balanced accuracy score
y_pred = logreg.predict(X_test)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print("Balanced Accuracy Score:", balanced_accuracy)

# %%
# Display the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# %%
# Print the imbalanced classification report
y_pred = logreg.predict(X_test)

classification_report = classification_report_imbalanced(y_test, y_pred)

print("Imbalanced Classification Report:")
print(classification_report)
